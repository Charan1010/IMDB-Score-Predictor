# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("IMDB_MOVIE_DATA")

# %%
df.head()
# Out:
#    IMDB  MetaCritic  Runtime      Votes        Gross
# 0   8.8        74.0    148.0  1737545.0  292576195.0
# 1   8.1        63.0    138.0   948466.0  128012934.0
# 2   8.3        92.0    103.0   646084.0  415004880.0
# 3   8.0        79.0    108.0   621643.0  106954678.0
# 4   7.0        57.0    124.0   611148.0  312433331.0

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd7c132310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd7c0f4190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd7c0aa1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd7c060390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd7c017550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd7c04d710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75ff38d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75fa9a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75f61c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75f18e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75ed0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75e931d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75e4b390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75e01550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75e396d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75df2890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75da8a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75d60c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75d1add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75cd2f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75c94190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd7c5fe1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75c7a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75c2e550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbd75be2710>]],
#       dtype=object)

# %%
sns.heatmap(df.corr(),square=True,annot=True)

# %%
train,test=train_test_split(df,test_size=0.20)

# %%
x_train=train.drop("IMDB",axis=1)

# %%
y_train=train["IMDB"]

# %%
x_test=test.drop("IMDB",axis=1)
y_test=test["IMDB"]

# %%
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
result_df=pd.DataFrame({"Predicted":reg.predict(x_test),"Actual":y_test})

# %%
#Mean Square Error
np.mean((result_df["Predicted"]-result_df["Actual"])**2)
# Out:
# 0.1258533062079998

# %%
result_df.head()
# Out:
#      Actual  Predicted
# 97      6.9   7.530416
# 47      9.0   9.290324
# 483     7.6   7.647873
# 133     7.2   7.258287
# 90      8.7   8.563095

# %%
sns.heatmap(result_df.corr(),square=True,annot=True)

# %%
plt.scatter(result_df["Predicted"],result_df["Actual"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(0,0.5,'Actual')

# %%
print "Accuracy score:  "+str(reg.score(x_test,y_test))
# Out:
# Accuracy score:  0.853564534923544

# %%
X=df.drop("IMDB",axis=1)
Y=df["IMDB"]

# %%
from sklearn.cross_validation import cross_val_score,cross_val_predict
from sklearn import metrics

# %%
scores = cross_val_score(reg,X, Y, cv=10)
print "Cross-validated scores:"+ str(scores)
# Out:
# Cross-validated scores:[0.83321416 0.67064096 0.875683   0.75612092 0.77995082 0.81685159
#  0.65578401 0.85382262 0.71557096 0.76906942]

# %%
predictions = cross_val_predict(reg, X, Y, cv=10)
plt.scatter(predictions, Y)
plt.xlabel("Predictions")
plt.ylabel("Actual")
# Out:
# Text(0,0.5,'Actual')

# %%
accuracy = metrics.r2_score(Y, predictions)
print "Cross-Predicted Accuracy:"+str( accuracy)
# Out:
# Cross-Predicted Accuracy:0.8215137803924464
